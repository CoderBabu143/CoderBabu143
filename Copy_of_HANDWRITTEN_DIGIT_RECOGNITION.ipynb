# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderBabu143/CoderBabu143/blob/main/Copy_of_HANDWRITTEN_DIGIT_RECOGNITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_digits

# %% [markdown]
# ![data.png](data:image/png;base64,...)

# %%
dataset=load_digits()

# %%
print(dataset.data)
print(dataset.target)
print(dataset.data.shape)
print(dataset.images.shape)
dataimageLength=len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %%
n=85
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()
dataset.images[n]
# Out:
# array([[ 0.,  0.,  0.,  1., 16.,  5.,  0.,  0.],
#        [ 0.,  0.,  0.,  5., 16., 11.,  0.,  0.],
#        [ 0.,  0.,  0., 12., 16., 11.,  0.,  0.],
#        [ 0.,  7., 12., 16., 16.,  7.,  0.,  0.],
#        [ 0.,  4.,  8., 12., 16.,  4.,  0.,  0.],
#        [ 0.,  0.,  0.,  9., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  0., 10., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  0.,  3., 13.,  5.,  0.,  0.]])

# %%
X=dataset.images.reshape((dataimageLength,-1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y=dataset.target
Y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=0.25,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %%
from sklearn import svm
model=svm.SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
n=999
result=model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n],cmap=plt.cm.gray_r,interpolation='nearest')
print('result')
print("\n")
plt.axis('off')
plt.title('%i'%result)
plt.show()
# Out:
# result

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# ***EVALUATE MODEL ACCURACY SCORE***

# %%
from sklearn.metrics import accuracy_score
print("ACCURACY OF THE MODEL:{0}%".format(accuracy_score(y_test,y_pred)*100))
# Out:
# ACCURACY OF THE MODEL:99.11111111111111%

# %% [markdown]
# ***PLAY WITH DIFFERENT METHOD***

# %%
from sklearn import svm
model1=svm.SVC(kernel='linear')
model2=svm.SVC(kernel='rbf')
model3=svm.SVC(gamma=0.001)
model4=svm.SVC(gamma=0.001,C=0.1)
model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
model4.fit(X_train,y_train)

y_predModel1=model1.predict(X_test)
y_predModel2=model2.predict(X_test)
y_predModel3=model3.predict(X_test)
y_predModel4=model4.predict(X_test)
print("ACCURACY of the Model 1:{0}%".format(accuracy_score(y_test,y_predModel1)*100))
print("ACCURACY of the Model 2:{0}%".format(accuracy_score(y_test,y_predModel2)*100))
print("ACCURACY of the Model 3:{0}%".format(accuracy_score(y_test,y_predModel3)*100))
print("ACCURACY of the Model 4:{0}%".format(accuracy_score(y_test,y_predModel4)*100))
# Out:
# ACCURACY of the Model 1:97.11111111111111%
# ACCURACY of the Model 2:99.11111111111111%
# ACCURACY of the Model 3:99.55555555555556%
# ACCURACY of the Model 4:96.66666666666667%
